# %% [markdown]
# # DOCUMENT
# ## SCOPE
# ランダムフォレストを実装します。

# %% [markdown]
# # Impliment Random Forest

# %%
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap, ListedColormap
import matplotlib as mpl

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, roc_curve, auc
from sklearn.ensemble import RandomForestClassifier

main_color = '#fe7e39'
sub_color = '#18216e'

# %% [markdown]
# ## データの準備
# この操作は**100_decisiontree.ipynb**と同様です。そのため１つのセルにまとめて処理を行います。

# %%
df = pd.read_csv('../datasets/preprocessed_data.csv')
display(df.head())
print(f'-----df shape: {df.shape}-----')
display(df.describe(include='all'))

for col in df.columns:
    if df[col].dtype == object:
        dummies = pd.get_dummies(df[col], drop_first=True, prefix=col)
        df = pd.concat([df.drop(col, axis=1), dummies], axis=1)
        
# split trainval data and test data
trainval = df.loc[:, ~df.columns.isin(['y_yes', 'saving', 'debt', 'duration'])]
X_trainval, X_test, y_trainval, y_test = train_test_split(trainval, df['y_yes'], test_size=0.2, random_state=0)
X_train, X_val, y_train, y_val = train_test_split(X_trainval, y_trainval, test_size=0.2, random_state=0)

print('-+-'*30)

print('X_train')
display(X_train)
print('y_train')
display(y_train)
# Out:
#    age          job  marital  education default  balance housing loan  \
# 0   27   management   single  secondary      no       35      no   no
# 1   54  blue-collar  married    primary      no      466      no   no
# 2   43  blue-collar  married  secondary      no      105      no  yes
# 3   31   technician   single  secondary      no       19      no   no
# 4   27   technician   single  secondary      no      126     yes  yes
#
#      contact  day_of_week month  duration  campaign  pdays  previous   y  \
# 0   cellular            4   jul       255         1     -1         0  no
# 1   cellular            4   jul       297         1     -1         0  no
# 2   cellular            4   jul       668         2     -1         0  no
# 3  telephone            4   jul        65         2     -1         0  no
# 4   cellular            4   jul       436         4     -1         0  no
#
#    saving  debt
# 0    35.0   NaN
# 1   466.0   NaN
# 2   105.0   NaN
# 3    19.0   NaN
# 4   126.0   NaN
# -----df shape: (30907, 18)-----
#                  age         job  marital  education default        balance  \
# count   30907.000000       30907    30907      30907   30907   30907.000000
# unique           NaN          11        3          3       2            NaN
# top              NaN  management  married  secondary      no            NaN
# freq             NaN        7329    18379      16004   30397            NaN
# mean       40.918918         NaN      NaN        NaN     NaN    1425.760701
# std        10.922583         NaN      NaN        NaN     NaN    3190.967030
# min        18.000000         NaN      NaN        NaN     NaN   -8019.000000
# 25%        32.000000         NaN      NaN        NaN     NaN      80.000000
# 50%        39.000000         NaN      NaN        NaN     NaN     473.000000
# 75%        48.000000         NaN      NaN        NaN     NaN    1502.500000
# max        95.000000         NaN      NaN        NaN     NaN  102127.000000
#
#        housing   loan   contact   day_of_week  month      duration  \
# count    30907  30907     30907  30907.000000  30907  30907.000000
# unique       2      2         2           NaN     12           NaN
# top         no     no  cellular           NaN    jul           NaN
# freq     15564  25787     28213           NaN   6336           NaN
# mean       NaN    NaN       NaN     15.967257    NaN    260.485003
# std        NaN    NaN       NaN      8.226736    NaN    257.783963
# min        NaN    NaN       NaN      1.000000    NaN      0.000000
# 25%        NaN    NaN       NaN      9.000000    NaN    104.000000
# 50%        NaN    NaN       NaN     16.000000    NaN    181.000000
# 75%        NaN    NaN       NaN     21.000000    NaN    322.000000
# max        NaN    NaN       NaN     31.000000    NaN   4918.000000
#
#             campaign         pdays      previous      y         saving  \
# count   30907.000000  30907.000000  30907.000000  30907   28683.000000
# unique           NaN           NaN           NaN      2            NaN
# top              NaN           NaN           NaN     no            NaN
# freq             NaN           NaN           NaN  26394            NaN
# mean        2.751318     55.944835      0.808490    NaN    1560.796256
# std         2.954412    112.726930      2.706169    NaN    3272.041883
# min         1.000000     -1.000000      0.000000    NaN       0.000000
# 25%         1.000000     -1.000000      0.000000    NaN     145.000000
# 50%         2.000000     -1.000000      0.000000    NaN     553.000000
# 75%         3.000000     10.000000      1.000000    NaN    1637.000000
# max        50.000000    871.000000    275.000000    NaN  102127.000000
#
#                debt
# count   2224.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean    -315.797212
# std      395.596465
# min    -8019.000000
# 25%     -413.250000
# 50%     -225.000000
# 75%      -90.000000
# max       -1.000000
# -+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+--+-
# X_train
#        age  balance  day_of_week  campaign  pdays  previous  job_blue-collar  \
# 13930   32     3314           21         2     -1         0             True
# 12142   47     1095           18         1    110         2            False
# 5607    28       22           31         3     -1         0            False
# 23392   43        3           13         1    174         2             True
# 15803   34      926            2         2     -1         0            False
# ...    ...      ...          ...       ...    ...       ...              ...
# 11938   41      159           18         1     -1         0            False
# 4533    34      262           28         3     -1         0            False
# 8917    45      638           20         9     -1         0            False
# 11580   31      761           18         2     -1         0             True
# 25030   34     1012           15         3     -1         0            False
#
#        job_entrepreneur  job_housemaid  job_management  ...  month_dec  \
# 13930             False          False           False  ...      False
# 12142             False          False           False  ...      False
# 5607              False          False            True  ...      False
# 23392             False          False           False  ...      False
# 15803             False          False            True  ...      False
# ...                 ...            ...             ...  ...        ...
# 11938             False          False           False  ...      False
# 4533              False          False           False  ...      False
# 8917              False          False           False  ...      False
# 11580             False          False           False  ...      False
# 25030             False          False            True  ...      False
#
#        month_feb  month_jan  month_jul  month_jun  month_mar  month_may  \
# 13930      False      False      False      False      False      False
# 12142      False      False      False      False      False      False
# 5607       False      False       True      False      False      False
# 23392      False      False      False      False      False       True
# 15803       True      False      False      False      False      False
# ...          ...        ...        ...        ...        ...        ...
# 11938      False      False      False      False      False      False
# 4533       False      False       True      False      False      False
# 8917       False      False      False      False      False      False
# 11580      False      False      False      False      False      False
# 25030      False      False      False      False      False       True
#
#        month_nov  month_oct  month_sep
# 13930       True      False      False
# 12142       True      False      False
# 5607       False      False      False
# 23392      False      False      False
# 15803      False      False      False
# ...          ...        ...        ...
# 11938       True      False      False
# 4533       False      False      False
# 8917       False      False      False
# 11580       True      False      False
# 25030      False      False      False
#
# [19780 rows x 35 columns]
# y_train
# 13930    False
# 12142    False
# 5607     False
# 23392    False
# 15803    False
#          ...
# 11938    False
# 4533     False
# 8917     False
# 11580     True
# 25030    False
# Name: y_yes, Length: 19780, dtype: bool

# %% [markdown]
# ## 学習と効果検証

# %%
start = time.time()
clf = RandomForestClassifier(random_state=0)
clf.fit(X_train, y_train)
y_test_pred = clf.predict(X_test)
val_accuracy = accuracy_score(y_test, y_test_pred)
print(f'Test Accuracy: {val_accuracy:.2f}')
print(classification_report(y_test, y_test_pred))
end = time.time()
print(f"Processing Time: {end - start}")
# Out:
# Test Accuracy: 0.86
#               precision    recall  f1-score   support
#
#        False       0.88      0.97      0.92      5288
#         True       0.54      0.19      0.29       894
#
#     accuracy                           0.86      6182
#    macro avg       0.71      0.58      0.60      6182
# weighted avg       0.83      0.86      0.83      6182
#
# Processing Time: 1.1694560050964355

# %%
y_test_proba = clf.predict_proba(X_test)[:, 1]

# ROC曲線の値を計算
fpr, tpr, thresholds = roc_curve(y_test, y_test_proba)

# AUC（Area Under the Curve）を計算
roc_auc = auc(fpr, tpr)

plt.figure(figsize=(8, 6))
ax = plt.gca()

[ax.spines[spine].set_visible(False) for spine in ['right', 'top']]

ax.plot([0, 1], [0, 1], 'k--', color=sub_color, label='Random Guessing')
ax.plot(fpr, tpr, color=main_color, label=f'ROC Curve (AUC = {roc_auc:.2f})')
ax.set_xlabel('False Positive Rate')
ax.set_ylabel('True Positive Rate')
ax.set_title('ROC Curve')
ax.legend(loc='lower right')

plt.show()
# Out:
# /tmp/ipykernel_77600/599180515.py:14: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   ax.plot([0, 1], [0, 1], 'k--', color=sub_color, label='Random Guessing')

# %%
feature_importance= {}
[feature_importance.update([(key, value)]) for key, value in zip(clf.feature_names_in_, clf.feature_importances_)]

importance_feature_list = []
feature_list = []
for key, value in feature_importance.items():
    feature_list.append(key)
    if value >= 0.01:
        importance_feature_list.append(key)

# %%
fig, ax = plt.subplots(figsize=((10, 7)))

ax.barh(y=feature_list[::-1], width=list(feature_importance.values())[::-1], color=main_color)
ax.set_xlabel('')
ax.set_ylabel('Feature Name')
ax.set_title('Feature Importance')
plt.tight_layout()
